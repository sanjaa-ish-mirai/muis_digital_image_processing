# %% [markdown]
# # Exersice 1-2

# %%
import numpy as np
import matplotlib.pyplot as plt
get_ipython().run_line_magic('matplotlib','inline')

# %%
import cv2

# %%
cv2.__version__
# Out:
# '4.12.0'

# %%
img = cv2.imread('../images/himalayas.jpg')

# %%
img.shape
# Out:
# (341, 512, 3)

# %%
plt.imshow(img)

# %%
cor_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(cor_img)

# %%
img2 = cv2.imread('../images/bmp25.jpg')

# %%
plt.imshow(img2)

# %%
cor2_img = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(cor2_img)

# %%
gray_img = cv2.imread('../images/bmp25.jpg', cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(gray_img, cmap='gray')

# %%
small_img = cv2.resize(cor2_img, (100, 200))
plt.imshow(small_img)

# %%
ratio = 0.1
resize_img2a = cv2.resize(cor2_img, (0,0),cor2_img, ratio, ratio)

# %%
plt.imshow(resize_img2a)

# %%
print(cor2_img.shape)
print(resize_img2a.shape)
# Out:
# (600, 800, 3)
# (60, 80, 3)

# %%
img2a = cv2.flip(cor2_img, 0)
plt.imshow(img2a)

# %%
img2b = cv2.flip(cor2_img, 1)
plt.imshow(img2b)

# %%
img2c = cv2.flip(cor2_img, -1)
plt.imshow(img2c)

# %%
cv2.imwrite('images/new_fliped_img.jpg',img2c);

# %%
cv2.imwrite('images/new_fliped_img_RGB.jpg',cv2.cvtColor(img2c,cv2.COLOR_RGB2BGR));

# %%
lab_img = cv2.cvtColor(img, cv2.COLOR_BGR2Lab)

# %%
plt.imshow(lab_img[::,::,0], cmap='gray')

# %%
plt.imshow(lab_img[:, :, 1],cmap='gray')

# %%
plt.imshow(lab_img[:, :, 2],cmap='gray')

# %%
import cv2
img = cv2.imread('../images/RGB-color-model.jpg')
while True:
    cv2.imshow('image window', img) # Display the image in a window
    if cv2.waitKey(1) & 0xFF == 27: # 27 is the Esc key
        break
cv2.destroyAllWindows()
